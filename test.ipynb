# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/MyDrive/Daou_FiveGuys
# Out:
# /content/drive/MyDrive/Daou_FiveGuys

# %%
# !git clone https://[github 이름]:[토큰]@github.com/Daou-FiveGuys/colab.git
# Out:
# Cloning into 'colab'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.

# %%
# !git config --global user.email '6ukeem@gmail.com'
# !git config --global user.name '6-keem'

# %%
cd colab
# Out:
# /content/drive/MyDrive/Daou_FiveGuys/colab
